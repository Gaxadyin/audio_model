# %%
from predict import PhonemePredictor, load_audio_segments, extract_mfcc_features
from data_read import extract_melspectrogram_features
import numpy as np

# %%
predictor = PhonemePredictor()
# Out:
# Model weights loaded from best_model.pt

# %%
import IPython
import IPython.display

IPython.display.Audio("./test.wav")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
predictor = PhonemePredictor()
# Out:
# Model weights loaded from best_model.pt

# %%
# 这里修改为测试音频文件的路径
audio_file = "./test.wav"

results = predictor.predict_audio(audio_file, get_intensity=True)

print(np.array(results))
# Out:
# ['P' 'P' 'SIL' 'SIL' 'SIL' 'SIL' 'SIL' 'K' 'K' 'T' 'AH' 'AH' 'AH' 'AH'
#  'AH' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'L' 'OW' 'OW' 'OW' 'OW' 'OW' 'OW' 'OW'
#  'OW' 'OW' 'OW' 'OW' 'OW' 'OW' 'OW' 'OW' 'OW' 'HH' 'HH' 'HH' 'HH' 'HH'
#  'HH' 'HH' 'HH' 'HH' 'AW' 'AW' 'AW' 'AW' 'AW' 'AW' 'AW' 'AW' 'AW' 'AW'
#  'ER' 'ER' 'ER' 'ER' 'ER' 'ER' 'ER' 'T' 'ER' 'D' 'UW' 'IH' 'IH' 'IY' 'IH'
#  'IY' 'D' 'D' 'D' 'D' 'D' 'D' 'D' 'D' 'UW' 'UW' 'UW' 'UW' 'UW' 'UW' 'UW'
#  'UW' 'IH' 'IH' 'IH' 'IH' 'IH' 'IH' 'NG' 'NG' 'NG' 'NG' 'NG' 'N' 'N' 'T'
#  'T' 'T' 'T' 'T' 'T' 'T' 'IH' 'IH' 'AH' 'D' 'D' 'D' 'D' 'D' 'EY' 'EY' 'EY'
#  'EY' 'EY' 'EY' 'EY' 'EY' 'EY' 'IY' 'EY' 'EY' 'EY' 'EY' 'EY' 'SIL' 'SIL'
#  'SIL' 'SIL' 'EY' 'IY' 'IY' 'SIL' 'SIL' 'SIL' 'SIL' 'SIL' 'SIL' 'SIL'
#  'SIL' 'SIL' 'SIL' 'SIL' 'SIL' 'SIL' 'SIL' 'SIL' 'SIL' 'SIL' 'SIL' 'SIL'
#  'SIL' 'SIL' 'SIL' 'SIL' 'SIL' 'SIL' 'SIL' 'SIL' 'SIL' 'SIL' 'SIL' 'SIL'
#  'SIL' 'SIL' 'SIL' 'SIL' 'SIL' 'SIL' 'SIL' 'SIL' 'SIL' 'SIL' 'SIL' 'SIL']
